# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Medias.xlsx')
display(df)
# Out:
#      Ano Região Ufq  Código do Município           Município Localização  \
# 0   2019    Sul  SC              4202008  Balneário Camboriú       Total
# 1   2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 2   2019    Sul  SC              4202008  Balneário Camboriú       Total
# 3   2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 4   2019    Sul  SC              4202008  Balneário Camboriú       Total
# 5   2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 6   2019    Sul  SC              4202008  Balneário Camboriú       Total
# 7   2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 8   2019    Sul  SC              4202008  Balneário Camboriú       Total
# 9   2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 10  2020    Sul  SC              4202008  Balneário Camboriú       Total
# 11  2020    Sul  SC              4202008  Balneário Camboriú      Urbana
# ...

# %%
df.columns
# Out:
# Index(['Ano', 'Região', 'Ufq', 'Código do Município', 'Município',
#        'Localização', 'Dependência Administrativa', 'Total Educação Infantil',
#        'Creche', 'Pré escola', 'Total Ensino Fundamental', 'Anos Iniciais',
#        'Anos Finais', '1º Ano', '2° ano', '3° ano', '4° ano', '5° ano',
#        '6° ano', ' 7° ano', ' 8° ano', '9° ano',
#        'Turmas Multietapa, Multi ou Correção de Fluxo 2', 'Total', '1ª série',
#        '2ª série', '3ª série', '4ª série', 'Não-Seriado'],
#       dtype='object')

# %%
df = df.rename(columns={'Ufq' : 'UF'})
df.head()
# Out:
#     Ano Região  UF  Código do Município           Município Localização  \
# 0  2019    Sul  SC              4202008  Balneário Camboriú       Total
# 1  2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 2  2019    Sul  SC              4202008  Balneário Camboriú       Total
# 3  2019    Sul  SC              4202008  Balneário Camboriú      Urbana
# 4  2019    Sul  SC              4202008  Balneário Camboriú       Total
#
#   Dependência Administrativa Total Educação Infantil Creche Pré escola  ...  \
# 0                      Total                    15.5   16.3       14.8  ...
# 1                      Total                    15.5   16.3       14.8  ...
# 2                   Estadual                      --     --         --  ...
# 3                   Estadual                      --     --         --  ...
# 4                  Municipal                    16.8   18.5       15.4  ...
#
# ...
